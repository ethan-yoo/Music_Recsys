# %%
# !pip install datasets
# !pip install transformers

# %%
import time
import numpy as np
import pandas as pd

import tensorflow as tf
import torch

import re
import os

import datasets
from datasets import load_dataset, load_metric, ClassLabel, Sequence, Dataset

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split as tts

from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, EarlyStoppingCallback
import matplotlib.pyplot as plt

print('torch version:', torch.__version__)
print('tf version:', tf.__version__)
# Out:
# torch version: 1.12.1+cu113
# tf version: 2.9.2

# %%
# random seed fix
import random

random.seed(2022)
torch.manual_seed(2022)
np.random.seed(2022)

# %%
# data load
sentiment_data = pd.read_csv('/content/data_labeling.csv', encoding='cp949')
sentiment_data.head()
# Out:
#                                              content emotion  label
# 0                           아내가 드디어 출산하게 되어서 정말 신이 나      기쁨      0
# 1             당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야      긴장      1
# 2             고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워      긴장      1
# 3        재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야 너무 행복해      기쁨      0
# 4  이제 곧 은퇴할 시기가 되었어 내가 먼저 은퇴를 하고 육 개월 후에 남편도 은퇴를 ...      긴장      1

# %%
sentiment_data.isna().sum()
# Out:
# content    0
# emotion    0
# label      0
# dtype: int64

# %%
sentiment_data.drop('emotion', axis=1, inplace=True)
sentiment_data.head()
# Out:
#                                              content  label
# 0                           아내가 드디어 출산하게 되어서 정말 신이 나      0
# 1             당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야      1
# 2             고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워      1
# 3        재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야 너무 행복해      0
# 4  이제 곧 은퇴할 시기가 되었어 내가 먼저 은퇴를 하고 육 개월 후에 남편도 은퇴를 ...      1

# %%
# data split
train_data, test_data = tts(sentiment_data, test_size=0.2)
print(train_data.shape, test_data.shape)
# Out:
# (66088, 2) (16522, 2)

# %%
# model setting
num_labels = 6
model = AutoModelForSequenceClassification.from_pretrained('klue/roberta-large', num_labels=num_labels)
tokenizer = AutoTokenizer.from_pretrained('klue/roberta-large')
# Out:
# Downloading:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.35G [00:00<?, ?B/s]
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/752k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
# preprocessing function
def preprocess_function(data):
    return tokenizer(
        # tokenizing
        data['content'],

        max_length=512,

        # 최대 길이보다 긴 시퀀스는 최대 길이에 맞춰 자름
        truncation=True,

        # tokenizer가 token_type_ids를 return하지 않게 함
        # roberta는 필요없기 때문
        return_token_type_ids=False,
    )

# %%
# dataset transform
df_train = pd.DataFrame({'content':train_data['content'], 'label':train_data['label']})
dataset_train = Dataset.from_pandas(df_train)

df_val = pd.DataFrame({'content':test_data['content'], 'label':test_data['label']})
dataset_val = Dataset.from_pandas(df_val)

# %%
tokenized_train_datasets = dataset_train.map(preprocess_function, batched=True)
tokenized_val_datasets = dataset_val.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/67 [00:00<?, ?ba/s]
#   0%|          | 0/17 [00:00<?, ?ba/s]

# %%
def eval_metric(pred, real):
    f1 = {'micro_f1':f1_score(real, pred, average='micro')}
    return f1

# eval metric
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    result = eval_metric(predictions, labels)
    return result

# %%
metric_name = "micro_f1"

# batch size 지정
batch_size = 8
num_train_epochs = 20

# path 설정
trained_model_path = '/content'

args = TrainingArguments(
    output_dir=trained_model_path,
    overwrite_output_dir=True,
    # evaluation_strategy="epoch",
    evaluation_strategy="steps",
    learning_rate=1e-6,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_train_epochs,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model=metric_name,
    save_total_limit=2,
    tpu_num_cores = 85,
    seed = 2022,
    data_seed = 2022,
    dataloader_pin_memory = True,
    optim = 'adafactor'
)

trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_train_datasets,
    eval_dataset=tokenized_val_datasets,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=5)],
)

trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 66088
#   Num Epochs = 20
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 165220
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='15000' max='165220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 15000/165220 2:40:37 < 26:48:49, 1.56 it/s, Epoch 1/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Micro F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.527800</td>
#       <td>1.262699</td>
#       <td>0.522879</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.099100</td>
#       <td>0.974597</td>
#       <td>0.633398</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.986600</td>
#       <td>0.908454</td>
#       <td>0.653553</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.893300</td>
#       <td>0.876664</td>
#       <td>0.667776</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.878300</td>
#       <td>0.847158</td>
#       <td>0.679458</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.839400</td>
#       <td>0.833992</td>
#       <td>0.685268</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.842600</td>
#       <td>0.813092</td>
#       <td>0.695678</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.793100</td>
#       <td>0.798448</td>
#       <td>0.701005</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.814400</td>
#       <td>0.798859</td>
#       <td>0.696647</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.787900</td>
#       <td>0.810565</td>
#       <td>0.699007</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.831600</td>
#       <td>0.785453</td>
#       <td>0.705847</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.771300</td>
#       <td>0.787801</td>
#       <td>0.708449</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.771800</td>
#       <td>0.794265</td>
#       <td>0.708449</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.771700</td>
#       <td>0.792271</td>
#       <td>0.708389</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.768700</td>
#       <td>0.767070</td>
#       <td>0.716378</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.758700</td>
#       <td>0.763399</td>
#       <td>0.714018</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.753200</td>
#       <td>0.766506</td>
#       <td>0.717286</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.718700</td>
#       <td>0.783250</td>
#       <td>0.712626</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.696400</td>
#       <td>0.790741</td>
#       <td>0.713412</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.740400</td>
#       <td>0.772853</td>
#       <td>0.718375</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.726100</td>
#       <td>0.767510</td>
#       <td>0.720615</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.714000</td>
#       <td>0.773042</td>
#       <td>0.719162</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.711000</td>
#       <td>0.781877</td>
#       <td>0.712444</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.716200</td>
#       <td>0.783167</td>
#       <td>0.719647</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.722500</td>
#       <td>0.761137</td>
#       <td>0.722854</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.716600</td>
#       <td>0.759831</td>
#       <td>0.720675</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.720400</td>
#       <td>0.755456</td>
#       <td>0.722491</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.723800</td>
#       <td>0.755871</td>
#       <td>0.719525</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.752700</td>
#       <td>0.754662</td>
#       <td>0.719283</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.700200</td>
#       <td>0.769384</td>
#       <td>0.721704</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-500
# Configuration saved in /content/checkpoint-500/config.json
# Model weights saved in /content/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-1000
# Configuration saved in /content/checkpoint-1000/config.json
# Model weights saved in /content/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-1500
# Configuration saved in /content/checkpoint-1500/config.json
# Model weights saved in /content/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-1500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-2000
# Configuration saved in /content/checkpoint-2000/config.json
# Model weights saved in /content/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-2500
# Configuration saved in /content/checkpoint-2500/config.json
# Model weights saved in /content/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-3000
# Configuration saved in /content/checkpoint-3000/config.json
# Model weights saved in /content/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-3500
# Configuration saved in /content/checkpoint-3500/config.json
# Model weights saved in /content/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-4000
# Configuration saved in /content/checkpoint-4000/config.json
# Model weights saved in /content/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-4500
# Configuration saved in /content/checkpoint-4500/config.json
# Model weights saved in /content/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-5000
# Configuration saved in /content/checkpoint-5000/config.json
# Model weights saved in /content/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-5500
# Configuration saved in /content/checkpoint-5500/config.json
# Model weights saved in /content/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-6000
# Configuration saved in /content/checkpoint-6000/config.json
# Model weights saved in /content/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-6500
# Configuration saved in /content/checkpoint-6500/config.json
# Model weights saved in /content/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-7000
# Configuration saved in /content/checkpoint-7000/config.json
# Model weights saved in /content/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-7500
# Configuration saved in /content/checkpoint-7500/config.json
# Model weights saved in /content/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-8000
# Configuration saved in /content/checkpoint-8000/config.json
# Model weights saved in /content/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-8500
# Configuration saved in /content/checkpoint-8500/config.json
# Model weights saved in /content/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-7500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-9000
# Configuration saved in /content/checkpoint-9000/config.json
# Model weights saved in /content/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-9500
# Configuration saved in /content/checkpoint-9500/config.json
# Model weights saved in /content/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-10000
# Configuration saved in /content/checkpoint-10000/config.json
# Model weights saved in /content/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-8500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-10500
# Configuration saved in /content/checkpoint-10500/config.json
# Model weights saved in /content/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-9500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-11000
# Configuration saved in /content/checkpoint-11000/config.json
# Model weights saved in /content/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-11500
# Configuration saved in /content/checkpoint-11500/config.json
# Model weights saved in /content/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-11500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-12000
# Configuration saved in /content/checkpoint-12000/config.json
# Model weights saved in /content/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-12000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-11500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-12500
# Configuration saved in /content/checkpoint-12500/config.json
# Model weights saved in /content/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-10500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-13000
# Configuration saved in /content/checkpoint-13000/config.json
# Model weights saved in /content/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-13500
# Configuration saved in /content/checkpoint-13500/config.json
# Model weights saved in /content/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-14000
# Configuration saved in /content/checkpoint-14000/config.json
# Model weights saved in /content/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-13500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-14500
# Configuration saved in /content/checkpoint-14500/config.json
# Model weights saved in /content/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-14500/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-14000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, content. If __index_level_0__, content are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 16522
#   Batch size = 8
# Saving model checkpoint to /content/checkpoint-15000
# Configuration saved in /content/checkpoint-15000/config.json
# Model weights saved in /content/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/checkpoint-15000/special_tokens_map.json
# Deleting older checkpoint [/content/checkpoint-14500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/checkpoint-12500 (score: 0.7228543759835371).
# TrainOutput(global_step=15000, training_loss=0.8082748616536458, metrics={'train_runtime': 9640.9298, 'train_samples_per_second': 137.099, 'train_steps_per_second': 17.137, 'total_flos': 7194024894862080.0, 'train_loss': 0.8082748616536458, 'epoch': 1.82})
